# %%
from pytezos import pytezos

# %%
pytezos = pytezos.using(shell='testnet')

# %%
ci = pytezos.contract('KT1DMYxvZCqSVcpea8t6xdVdoDRgPHY3x9sD')
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-11-6f70e92aa730> in <module>
# ----> 1 ci = pytezos.contract('KT1DMYxvZCqSVcpea8t6xdVdoDRgPHY3x9sD')
#
# /usr/local/lib/python3.7/site-packages/pytezos/tools/docstring.py in __call__(self, *args, **kwargs)
#      65
#      66                 def __call__(self, *args, **kwargs):
# ---> 67                     return method(self.class_instance, *args, **kwargs)
#      68
#      69                 def __repr__(self):
#
# /usr/local/lib/python3.7/site-packages/pytezos/client.py in contract(self, contract_id)
#      97         :rtype: ContractInterface
#      98         """
# ---> 99         return self._get_contract_interface(contract_id)
#     100
#     101     def nft_app(self, contract_id) -> ContractInterface:
#
# /usr/local/lib/python3.7/site-packages/pytezos/client.py in _get_contract_interface(self, contract_id, factory)
#      88             shell=self.shell,
#      89             key=self.key,
# ---> 90             factory=factory
#      91         )
#      92
#
# /usr/local/lib/python3.7/site-packages/pytezos/michelson/interface.py in __init__(self, address, contract, factory, shell, key)
#     327         if contract is None:
#     328             assert address is not None
# --> 329             code = self.shell.contracts[address].code()
#     330             contract = factory.from_micheline(code)
#     331
#
# /usr/local/lib/python3.7/site-packages/pytezos/tools/docstring.py in __call__(self, *args, **kwargs)
#      65
#      66                 def __call__(self, *args, **kwargs):
# ---> 67                     return method(self.class_instance, *args, **kwargs)
#      68
#      69                 def __repr__(self):
#
# /usr/local/lib/python3.7/site-packages/pytezos/rpc/protocol.py in code(self)
#     172         :returns: Micheline expression
#     173         """
# --> 174         return self().get('script', {}).get('code')
#     175
#     176
#
# /usr/local/lib/python3.7/site-packages/pytezos/rpc/query.py in __call__(self, **params)
#     102             path=self.path,
#     103             params=params,
# --> 104             caching=self._caching
#     105         )
#     106
#
# /usr/local/lib/python3.7/site-packages/pytezos/rpc/node.py in get(self, path, params, caching, cache_key, timeout)
#     103                 return self._cache[cache_key]
#     104
# --> 105         res = self.request('GET', path, params=params, timeout=timeout).json()
#     106         if caching and self.caching:
#     107             self._cache[cache_key] = res
#
# /usr/local/lib/python3.7/site-packages/pytezos/rpc/node.py in request(self, method, path, **kwargs)
#      85                 'user-agent': 'PyTezos'
#      86             },
# ---> 87             **kwargs
#      88         )
#      89         if res.status_code == 404:
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     514             hooks=hooks,
#     515         )
# --> 516         prep = self.prepare_request(req)
#     517
#     518         proxies = proxies or {}
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in prepare_request(self, request)
#     457             auth=merge_setting(auth, self.auth),
#     458             cookies=merged_cookies,
# --> 459             hooks=merge_hooks(request.hooks, self.hooks),
#     460         )
#     461         return p
#
# /usr/local/lib/python3.7/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     312
#     313         self.prepare_method(method)
# --> 314         self.prepare_url(url, params)
#     315         self.prepare_headers(headers)
#     316         self.prepare_cookies(cookies)
#
# /usr/local/lib/python3.7/site-packages/requests/models.py in prepare_url(self, url, params)
#     386             error = error.format(to_native_string(url, 'utf8'))
#     387
# --> 388             raise MissingSchema(error)
#     389
#     390         if not host:
#
# MissingSchema: Invalid URL 'testnet/chains/main/blocks/head/context/contracts/KT1DMYxvZCqSVcpea8t6xdVdoDRgPHY3x9sD': No schema supplied. Perhaps you meant http://testnet/chains/main/blocks/head/context/contracts/KT1DMYxvZCqSVcpea8t6xdVdoDRgPHY3x9sD?
